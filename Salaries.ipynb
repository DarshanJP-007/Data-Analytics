# %%
# We are importing necesasry libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#

df=pd.read_csv(r"C:\Users\darsh\Downloads\Python\Assignment\Salaries.csv")
# Out:
# C:\Users\darsh\AppData\Local\Temp\ipykernel_3392\3728262740.py:3: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(r"C:\Users\darsh\Downloads\Python\Assignment\Salaries.csv")

# %%
df.head(10)
# Out:
#    Id        EmployeeName                                        JobTitle  \
# 0   1      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5   6      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6   7           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7   8       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8   9      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  10  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# ...

# %%
df.tail(10)
# Out:
#             Id      EmployeeName                      JobTitle       BasePay  \
# 148644  148645      Randy D Winn  Stationary Eng, Sewage Plant          0.00
# 148645  148646  Carolyn A Wilson     Human Services Technician          0.00
# 148646  148647      Not provided                  Not provided  Not Provided
# 148647  148648    Joann Anderson   Communications Dispatcher 2          0.00
# 148648  148649       Leon Walker                     Custodian          0.00
# 148649  148650     Roy I Tillery                     Custodian          0.00
# 148650  148651      Not provided                  Not provided  Not Provided
# 148651  148652      Not provided                  Not provided  Not Provided
# 148652  148653      Not provided                  Not provided  Not Provided
# 148653  148654         Joe Lopez    Counselor, Log Cabin Ranch          0.00
#
#          OvertimePay      OtherPay      Benefits  TotalPay  TotalPayBenefits  \
# ...

# %%
df.shape
# Out:
# (148654, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %%
df.isna().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                605
# OvertimePay              0
# OtherPay                 0
# Benefits             36159
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              110535
# dtype: int64

# %% [markdown]
# #Column Manipulation

# %%
df1=df.drop(columns=["Id", "Notes", "Agency" ,"Status"])

# %%
df1.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %%
#Replace 'Not Provided' in the EmployeeName column with NaN.

df1["EmployeeName"].str.replace("Not provided","NaN")
# Out:
# 0            NATHANIEL FORD
# 1              GARY JIMENEZ
# 2            ALBERT PARDINI
# 3         CHRISTOPHER CHONG
# 4           PATRICK GARDNER
#                 ...
# 148649        Roy I Tillery
# 148650                  NaN
# 148651                  NaN
# 148652                  NaN
# 148653            Joe Lopez
# Name: EmployeeName, Length: 148654, dtype: object

# %%
#Replace 'Not Provided' in the EmployeeName column with NaN

df1["EmployeeName"]
df1.replace({"Not provided":"NaN"})
# Out:
#              EmployeeName                                        JobTitle  \
# 0          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148649      Roy I Tillery                                       Custodian
# 148650                NaN                                             NaN
# 148651                NaN                                             NaN
# 148652                NaN                                             NaN
# 148653          Joe Lopez                      Counselor, Log Cabin Ranch
#
#              BasePay   OvertimePay      OtherPay      Benefits   TotalPay  \
# ...

# %%
df1.dropna()
# Out:
#               EmployeeName                      JobTitle       BasePay  \
# 36159       Gary Altenberg  Lieutenant, Fire Suppression     128808.87
# 36160         Gregory Suhr               Chief of Police      302578.0
# 36161           Khoa Trinh   Electronic Maintenance Tech      111921.0
# 36162   Joanne Hayes-White        Chief, Fire Department     296943.01
# 36163    Frederick Binkley     EMT/Paramedic/Firefighter     126863.19
# ...                    ...                           ...           ...
# 148649       Roy I Tillery                     Custodian          0.00
# 148650        Not provided                  Not provided  Not Provided
# 148651        Not provided                  Not provided  Not Provided
# 148652        Not provided                  Not provided  Not Provided
# 148653           Joe Lopez    Counselor, Log Cabin Ranch          0.00
#
#          OvertimePay      OtherPay      Benefits   TotalPay  TotalPayBenefits  \
# ...

# %%
# The number of unique job titles

df1["JobTitle"].nunique()
# Out:
# 2159

# %%
# The occurrence of employee names (top 5 most common names)

df1["EmployeeName"].value_counts().head(5)
# Out:
# EmployeeName
# Kevin Lee       13
# William Wong    11
# Richard Lee     11
# Steven Lee      11
# John Chan        9
# Name: count, dtype: int64

# %%
# Avg basepay of employee

Avg_basepay=df1["BasePay"].mean
print(Avg_basepay)
# Out:
# <bound method Series.mean of 0            167411.18
# 1            155966.02
# 2            212739.13
# 3              77916.0
# 4             134401.6
#               ...
# 148649            0.00
# 148650    Not Provided
# 148651    Not Provided
# 148652    Not Provided
# 148653            0.00
# Name: BasePay, Length: 148654, dtype: object>

# %%
# Average BasePay of employees with the job title 

av_basepay=df1[["EmployeeName" ,"BasePay" ,"JobTitle"]].mean
print(av_basepay)
# Out:
# <bound method DataFrame.mean of              EmployeeName       BasePay  \
# 0          NATHANIEL FORD     167411.18
# 1            GARY JIMENEZ     155966.02
# 2          ALBERT PARDINI     212739.13
# 3       CHRISTOPHER CHONG       77916.0
# 4         PATRICK GARDNER      134401.6
# ...                   ...           ...
# 148649      Roy I Tillery          0.00
# 148650       Not provided  Not Provided
# 148651       Not provided  Not Provided
# 148652       Not provided  Not Provided
# 148653          Joe Lopez          0.00
#
#                                               JobTitle
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1                      CAPTAIN III (POLICE DEPARTMENT)
# 2                      CAPTAIN III (POLICE DEPARTMENT)
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                                                ...
# 148649                                       Custodian
# ...

# %%
# The top 5 highest-paid employees

df1.head().sort_values(by="TotalPay",ascending=False)
# Out:
#         EmployeeName                                        JobTitle  \
# 0     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# 1  155966.02   245131.88  137811.38      NaN  538909.28         538909.28
# 2  212739.13   106088.18    16452.6      NaN  335279.91         335279.91
# 3    77916.0    56120.71   198306.9      NaN  332343.61         332343.61
# 4   134401.6      9737.0  182234.59      NaN  326373.19         326373.19
#
#    Year
# 0  2011
# 1  2011
# 2  2011
# 3  2011
# 4  2011

# %%
# Median BasePay for each department

df1[["JobTitle","BasePay"]].median
# Out:
# <bound method DataFrame.median of                                               JobTitle       BasePay
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC       77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# 148649                                       Custodian          0.00
# 148650                                    Not provided  Not Provided
# 148651                                    Not provided  Not Provided
# 148652                                    Not provided  Not Provided
# 148653                      Counselor, Log Cabin Ranch          0.00
#
# [148654 rows x 2 columns]>

# %%
# The job title of 'ALBERT PARDINI'

df1.loc[df1["EmployeeName"]=="ALBERT PARDINI","JobTitle"]
# Out:
# 2    CAPTAIN III (POLICE DEPARTMENT)
# Name: JobTitle, dtype: object

# %%
# How much did 'ALBERT PARDINI' make (including benefits)

df1.loc[df1["EmployeeName"]=="ALBERT PARDINI","TotalPayBenefits"]
# Out:
# 2    335279.91
# Name: TotalPayBenefits, dtype: float64

# %%
# Converting 

df1["BasePay"]=pd.to_numeric(df1["BasePay"],errors='coerce')

# %%
# Name of the person with the highest BasePay

df1.loc[df1["BasePay"].astype(float).idxmax(),"EmployeeName"]
# Out:
# 'Gregory P Suhr'

# %%
# Employee with the lowest BasePay

df1.loc[df1["BasePay"].astype(float).idxmin(),"EmployeeName"]
# Out:
# 'Irwin Sidharta'

# %%
# Employee worked for the most number of years

df1["EmployeeName"].value_counts().idxmax()
# Out:
# 'Kevin Lee'

# %%
# Total number of employees in each department

df1["JobTitle"].value_counts()
# Out:
# JobTitle
# Transit Operator                      7036
# Special Nurse                         4389
# Registered Nurse                      3736
# Public Svc Aide-Public Works          2518
# Police Officer 3                      2421
#                                       ...
# Light Rail Vehicle Equip Eng             1
# Civil Case Settlmnt Specialist           1
# ADMINISTRATOR, SFGH MEDICAL CENTER       1
# CHIEF OF POLICE                          1
# Special Assistant 8                      1
# Name: count, Length: 2159, dtype: int64

# %%
# The top 5 most common job titles

df1["JobTitle"].value_counts().head(5)
# Out:
# JobTitle
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: count, dtype: int64

# %%
# How many job titles contain the word 'Captain'

df1["JobTitle"].str.contains("Captian").shape[0]
# Out:
# 148654

# %%
# the top 3 most common benefits

df1["TotalPayBenefits"].value_counts().head(3)
# Out:
# TotalPayBenefits
# 7959.18      263
# 123290.70     56
# 132242.50     49
# Name: count, dtype: int64

# %%
# Percentage of BasePay is missing in the dataset

float((df1["BasePay"].isna().sum()/len(df1))*100)
# Out:
# 0.40967616074912216

# %%
#  The top 3 years with the smallest TotalPayBenefits

df1.groupby("Year")["TotalPayBenefits"].sum().nsmallest(3)
# Out:
# Year
# 2011    2.594195e+09
# 2012    3.696940e+09
# 2013    3.814772e+09
# Name: TotalPayBenefits, dtype: float64

# %%
# Histogram of TotalPay

plt.hist(df1["TotalPay"], bins=10,alpha=0.5,edgecolor="black")
plt.ylabel("TotalPay")
plt.xlabel("Frequncy")
plt.title("Histogram")
plt.show()
